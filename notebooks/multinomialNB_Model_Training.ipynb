# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

import pandas as pd
import numpy as np

# %%
#df = pd.read_csv("C:/Users/chand/OneDrive/Documents/Bruh/final-project-190688910-190988840/data/processed/train_emotion_dataset.csv")
#dftest = pd.read_csv("C:/Users/chand/OneDrive/Documents/Bruh/final-project-190688910-190988840/data/processed/test_emotion_dataset.csv")
df = pd.read_csv("C:/Users/chand/OneDrive/Documents/Bruh/final-project-190688910-190988840/data/processed/combined_samples_gt.csv")
#dftest = pd.read_csv("C:/Users/chand/OneDrive/Documents/Bruh/final-project-190688910-190988840/data/processed/processed_test_sample_gt.csv")
df.head()
# Out:
#            ID                                              Tweet Sentiment  \
# 0  d1d7ed938d   great site photos fantastic useful visit pemb...  positive
# 1  be0a927a80  _n  too want ooze speaking either why lame jok...   neutral
# 2  6b4eb2871c                thanks link ive voted  ill send too  positive
# 3  9c503adc87             also liptons sparkling green tea gross   neutral
# 4  3e1f7acd3c  know lender was yea people definitely sucked b...  negative
#
#       Time     Age        Country  Population -2020  Land Area (KmÂ²)  \
# 0  morning   46-60          Egypt         102334404            995450
# 1     noon   60-70  Guinea-Bissau           1968001             28120
# 2     noon   21-30       Bulgaria           6948445            108560
# 3     noon   21-30        Somalia          15893222            627340
# 4    night  70-100         Monaco             39242                 1
#
#    Density (P/KmÂ²) Ground Truth
# 0               103    happiness
# 1                70           df
# 2                64           df
# 3                25      disgust
# 4             26337        anger

# %%
df['Ground Truth'].value_counts()
# Out:
# happiness    271
# sadness      220
# df           164
# anger         66
# disgust       34
# surprise      30
# fear          15
# Name: Ground Truth, dtype: int64

# %%
Xfeatures = df['Tweet']
ylabels = df['Ground Truth']
cv = CountVectorizer()
X = cv.fit_transform((Xfeatures.values.astype('U')).ravel())
cv.get_feature_names_out()
# Out:
# array(['____', '_a_hart', '_agwl', ..., 'zealand', 'zenjar', 'zilch'],
#       dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, ylabels, test_size=0.3, random_state=42)

#pipe_lr = Pipeline(steps=[("cv", CountVectorizer()), ("lr", LogisticRegression)])
#pipe_lr.fit(X_train, y_train)
nv_model = MultinomialNB()
nv_model.fit(X_train, y_train)
nv_model.score(X_test, y_test)
# Out:
# 0.44166666666666665

# %%
y_pred_for_nv = nv_model.predict(X_test)
y_pred_for_nv
# Out:
# array(['happiness', 'happiness', 'df', 'happiness', 'sadness', 'sadness',
#        'happiness', 'df', 'sadness', 'sadness', 'sadness', 'happiness',
#        'sadness', 'sadness', 'happiness', 'sadness', 'happiness',
#        'happiness', 'sadness', 'happiness', 'happiness', 'df',
#        'happiness', 'sadness', 'sadness', 'happiness', 'happiness',
#        'happiness', 'happiness', 'df', 'sadness', 'anger', 'happiness',
#        'anger', 'surprise', 'happiness', 'happiness', 'happiness',
#        'sadness', 'sadness', 'sadness', 'happiness', 'anger', 'df',
#        'anger', 'anger', 'anger', 'df', 'happiness', 'happiness',
#        'happiness', 'sadness', 'happiness', 'sadness', 'sadness',
#        'sadness', 'happiness', 'happiness', 'happiness', 'happiness',
#        'happiness', 'disgust', 'sadness', 'happiness', 'sadness',
#        'sadness', 'sadness', 'happiness', 'sadness', 'happiness',
#        'happiness', 'df', 'happiness', 'happiness', 'sadness',
#        'happiness', 'happiness', 'happiness', 'sadness', 'sadness',
#        'happiness', 'happiness', 'happiness', 'sadness', 'happiness',
#        'happiness', 'sadness', 'happiness', 'happiness', 'df', 'sadness',
#        'happiness', 'df', 'sadness', 'happiness', 'sadness', 'happiness',
#        'df', 'happiness', 'happiness', 'happiness', 'happiness',
#        'happiness', 'df', 'sadness', 'happiness', 'happiness',
#        'happiness', 'happiness', 'sadness', 'happiness', 'happiness',
#        'sadness', 'sadness', 'happiness', 'happiness', 'happiness',
#        'sadness', 'sadness', 'anger', 'happiness', 'happiness', 'sadness',
#        'sadness', 'happiness', 'happiness', 'df', 'sadness', 'happiness',
#        'sadness', 'happiness', 'sadness', 'happiness', 'happiness',
#        'happiness', 'sadness', 'happiness', 'sadness', 'anger', 'sadness',
#        'happiness', 'sadness', 'sadness', 'happiness', 'happiness',
#        'happiness', 'happiness', 'sadness', 'happiness', 'happiness',
#        'happiness', 'happiness', 'sadness', 'sadness', 'sadness',
#        'happiness', 'sadness', 'happiness', 'happiness', 'happiness',
#        'happiness', 'sadness', 'sadness', 'sadness', 'happiness',
#        'sadness', 'sadness', 'happiness', 'df', 'df', 'happiness', 'df',
#        'happiness', 'sadness', 'happiness', 'df', 'df', 'happiness',
#        'happiness', 'happiness', 'happiness', 'happiness', 'happiness',
#        'happiness', 'sadness', 'happiness', 'surprise', 'df', 'happiness',
#        'happiness', 'sadness', 'happiness', 'happiness', 'happiness',
#        'happiness', 'disgust', 'df', 'happiness', 'df', 'sadness',
#        'sadness', 'happiness', 'sadness', 'df', 'happiness', 'happiness',
#        'df', 'sadness', 'happiness', 'df', 'sadness', 'df', 'sadness',
#        'sadness', 'happiness', 'df', 'happiness', 'sadness', 'happiness',
#        'sadness', 'happiness', 'happiness', 'happiness', 'df',
#        'happiness', 'happiness', 'happiness', 'df', 'happiness',
#        'happiness', 'happiness', 'happiness', 'df', 'happiness',
#        'sadness', 'happiness', 'df', 'df', 'sadness', 'sadness'],
#       dtype='<U9')

# %%
test_text = ["I love love love this project this so much hehehehehhe"]
test_vector = cv.transform(test_text).toarray()

# %%
#make prediction:
nv_model.predict(test_vector)
# Out:
# array(['happiness'], dtype='<U9')

# %%
# checking prediction probability, percentage/confidence score:
nv_model.predict_proba(test_vector)
# Out:
# array([[2.01451003e-04, 4.16759787e-02, 1.37157729e-03, 4.83722069e-05,
#         8.10463639e-01, 1.46078035e-01, 1.60947331e-04]])

# %%
#get all classes for the model
nv_model.classes_
# Out:
# array(['anger', 'df', 'disgust', 'fear', 'happiness', 'sadness',
#        'surprise'], dtype='<U9')

# %%
np.max(nv_model.predict_proba(test_vector)) #max value percentage
# Out:
# 0.8104636389494826

# %%
#predict emotion function
def predicting_emotion_of_tweet(tweet, model):
    vector = cv.transform(tweet).toarray()
    prediction_of_model = model.predict(vector)
    prediction_probability = model.predict_proba(vector)
    prediction_percentage_for_every_tweet = dict(zip(model.classes_, prediction_probability[0]))
    print("Prediction: {}, Prediction_score: {}".format(prediction_of_model[0], np.max(prediction_probability)))
    return prediction_percentage_for_every_tweet

# %%
predicting_emotion_of_tweet(test_text, nv_model)
# Out:
# Prediction: happiness, Prediction_score: 0.8104636389494826
# {'anger': 0.00020145100331402923,
#  'df': 0.04167597867291938,
#  'disgust': 0.001371577293271555,
#  'fear': 4.83722069140945e-05,
#  'happiness': 0.8104636389494826,
#  'sadness': 0.14607803454278948,
#  'surprise': 0.00016094733130977743}

# %%
predicting_emotion_of_tweet(["I really dont like to run, in fact I hate hate hate running."], nv_model)
# Out:
# Prediction: anger, Prediction_score: 0.814140579567871
# {'anger': 0.814140579567871,
#  'df': 0.007511473262253188,
#  'disgust': 4.450257651450261e-05,
#  'fear': 5.4531422101118933e-05,
#  'happiness': 0.001494499546465835,
#  'sadness': 0.17649274648845575,
#  'surprise': 0.00026166713633245687}

# %%
## Model Evaluating:
print(classification_report(y_test, y_pred_for_nv))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        22
#           df       0.33      0.22      0.26        46
#      disgust       0.00      0.00      0.00         8
#         fear       0.00      0.00      0.00         4
#    happiness       0.46      0.67      0.54        85
#      sadness       0.53      0.59      0.56        66
#     surprise       0.00      0.00      0.00         9
#
#     accuracy                           0.44       240
#    macro avg       0.19      0.21      0.20       240
# weighted avg       0.37      0.44      0.40       240
# C:\Users\chand\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chand\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\chand\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Confusion Matrix
confusion_matrix(y_test, y_pred_for_nv)

#plot confusion matrix
#ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_for_nv), ylabels)
# Out:
# array([[ 0,  3,  0,  0,  8, 11,  0],
#        [ 1, 10,  0,  0, 28,  6,  1],
#        [ 1,  0,  0,  0,  4,  3,  0],
#        [ 0,  1,  0,  0,  3,  0,  0],
#        [ 5,  8,  2,  0, 57, 12,  1],
#        [ 1,  7,  0,  0, 19, 39,  0],
#        [ 0,  1,  0,  0,  6,  2,  0]], dtype=int64)

# %%
# make a predictions column and check what that is against the groud truth

df = df.dropna()
df['Predictions'] = ''
for i, row in df.iterrows():
    text = [row['Tweet']]
    vector = cv.transform(text).toarray()
    df.at[i, 'Predictions'] = nv_model.predict(vector)
    
df.head(30)
# Out:
#             ID                                              Tweet Sentiment  \
# 0   d1d7ed938d   great site photos fantastic useful visit pemb...  positive
# 1   be0a927a80  _n  too want ooze speaking either why lame jok...   neutral
# 2   6b4eb2871c                thanks link ive voted  ill send too  positive
# 3   9c503adc87             also liptons sparkling green tea gross   neutral
# 4   3e1f7acd3c  know lender was yea people definitely sucked b...  negative
# 5   c818fdf4b8                   sun turned blancmange sucks pale  negative
# 6   b01c96b216                                                you   neutral
# 7   c5a47367cc  come join fun first pitch legends game may th ...   neutral
# 8   a16aa7fcc4                           happy mothers day gr day  positive
# 9   553beefa8b  ever since orchid quit drinking bottle eating ...   neutral
# 10  905ae17f24  walk  workabout  minsthink makes worse improve...   neutral
# 11  684b2dcea7                                           good one  positive
# 12  c4cad35b0f                             comp deleted half apps  negative
# 13  5552d4fffb                               oh ladies suffer lol   neutral
# 14  9d605483af  mc john sim posit  yr passed softees stranded ...   neutral
# 15  20290b6985                  thats gorgeous ill check new pics  positive
# 16  c2484278c9  mm films usually handled fuji oh met girl san ...  negative
# 17  51f650a1a9  glad liked it hes done loads arrangements one ...  positive
# 18  54477f9f5c                        melissa_leah car wont start  negative
# 19  9c52e5ba66                        love days school one friday  positive
# 20  4e93939f99                               weekend standby duty   neutral
# 21  34b20a06ef  awoooogahhhhhh heheee hope get decently priced...  positive
# 22  66095230ee                                  spending qt hubby  positive
# 23  be266a8cef                         huh ill try for reason try   neutral
# 24  0435d42f80  mad hell someone stole pink  black leapord pri...  negative
# 25  54fb6ac46e  kisses screwed ill raggy old cat woman ha im p...  negative
# 26  aff624f133                        thanx tom love u  great day  positive
# 27  0ba8d6cdb3  actually planning working  wth alas meetings k...   neutral
# 28  4633886fcf            side  seat loner please starbucks there   neutral
# 29  4ce03d596c                                 want travel little   neutral
#
#        Time     Age                      Country  Population -2020  \
# 0   morning   46-60                        Egypt         102334404
# 1      noon   60-70                Guinea-Bissau           1968001
# 2      noon   21-30                     Bulgaria           6948445
# 3      noon   21-30                      Somalia          15893222
# 4     night  70-100                       Monaco             39242
# 5     night  70-100  Eswatini (fmr. "Swaziland")           1160164
# 6      noon   21-30                     Paraguay           7132538
# 7   morning    0-20                  Timor-Leste           1318445
# 8   morning    0-20                        Haiti          11402528
# 9      noon   60-70                    Nicaragua           6624554
# 10     noon   21-30                  Switzerland           8654622
# 11     noon   60-70                      Germany          83783942
# 12    night  70-100                      Comoros            869601
# 13  morning   46-60                       Rwanda          12952218
# 14  morning    0-20                  Timor-Leste           1318445
# 15     noon   60-70                      Denmark           5792202
# 16    night  70-100                 Sierra Leone           7976983
# 17  morning   46-60                     Dominica             71986
# 18  morning   46-60                      Ireland           4937786
# 19    night  70-100                     Pakistan         220892340
# 20     noon   60-70                        Libya           6871292
# 21    night   31-45                      Senegal          16743927
# 22    night   31-45               United Kingdom          67886011
# 23     noon   60-70                         Fiji            896445
# 24    night   31-45                       Mexico         128932753
# 25     noon   60-70                        Samoa            198414
# 26  morning    0-20                      Vanuatu            307145
# 27  morning   46-60                   Kazakhstan          18776707
# 28  morning    0-20                        Egypt         102334404
# 29     noon   21-30                      Grenada            112523
#
#     Land Area (KmÂ²)  Density (P/KmÂ²) Ground Truth  Predictions
# 0             995450               103    happiness  [happiness]
# 1              28120                70           df         [df]
# 2             108560                64           df  [happiness]
# 3             627340                25      disgust    [disgust]
# 4                  1             26337        anger      [anger]
# 5              17200                67      sadness    [sadness]
# 6             397300                18           df  [happiness]
# 7              14870                89    happiness  [happiness]
# 8              27560               414    happiness  [happiness]
# 9             120340                55     surprise   [surprise]
# 10             39500               219      sadness    [sadness]
# 11            348560               240           df  [happiness]
# 12              1861               467      sadness    [sadness]
# 13             24670               525           df  [happiness]
# 14             14870                89           df         [df]
# 15             42430               137    happiness  [happiness]
# 16             72180               111    happiness  [happiness]
# 17               750                96    happiness  [happiness]
# 18             68890                72      sadness    [sadness]
# 19            770880               287    happiness  [happiness]
# 20           1759540                 4           df         [df]
# 21            192530                87    happiness  [happiness]
# 22            241930               281    happiness  [happiness]
# 23             18270                49           df  [happiness]
# 24           1943950                66        anger      [anger]
# 25              2830                70    happiness  [happiness]
# 26             12200                25    happiness  [happiness]
# 27           2699700                 7           df         [df]
# 28            995450               103      sadness         [df]
# 29               340               331    happiness    [sadness]

# %%
df['Match'] = ''

for i, row in df.iterrows():
    if (row['Predictions'] == row['Ground Truth']):
        df.at[i, 'Match'] = True
    else:
        df.at[i, 'Match'] = False   

df.head(20)
# Out:
#             ID                                              Tweet Sentiment  \
# 0   d1d7ed938d   great site photos fantastic useful visit pemb...  positive
# 1   be0a927a80  _n  too want ooze speaking either why lame jok...   neutral
# 2   6b4eb2871c                thanks link ive voted  ill send too  positive
# 3   9c503adc87             also liptons sparkling green tea gross   neutral
# 4   3e1f7acd3c  know lender was yea people definitely sucked b...  negative
# 5   c818fdf4b8                   sun turned blancmange sucks pale  negative
# 6   b01c96b216                                                you   neutral
# 7   c5a47367cc  come join fun first pitch legends game may th ...   neutral
# 8   a16aa7fcc4                           happy mothers day gr day  positive
# 9   553beefa8b  ever since orchid quit drinking bottle eating ...   neutral
# 10  905ae17f24  walk  workabout  minsthink makes worse improve...   neutral
# 11  684b2dcea7                                           good one  positive
# 12  c4cad35b0f                             comp deleted half apps  negative
# 13  5552d4fffb                               oh ladies suffer lol   neutral
# 14  9d605483af  mc john sim posit  yr passed softees stranded ...   neutral
# 15  20290b6985                  thats gorgeous ill check new pics  positive
# 16  c2484278c9  mm films usually handled fuji oh met girl san ...  negative
# 17  51f650a1a9  glad liked it hes done loads arrangements one ...  positive
# 18  54477f9f5c                        melissa_leah car wont start  negative
# 19  9c52e5ba66                        love days school one friday  positive
#
#        Time     Age                      Country  Population -2020  \
# 0   morning   46-60                        Egypt         102334404
# 1      noon   60-70                Guinea-Bissau           1968001
# 2      noon   21-30                     Bulgaria           6948445
# 3      noon   21-30                      Somalia          15893222
# 4     night  70-100                       Monaco             39242
# 5     night  70-100  Eswatini (fmr. "Swaziland")           1160164
# 6      noon   21-30                     Paraguay           7132538
# 7   morning    0-20                  Timor-Leste           1318445
# 8   morning    0-20                        Haiti          11402528
# 9      noon   60-70                    Nicaragua           6624554
# 10     noon   21-30                  Switzerland           8654622
# 11     noon   60-70                      Germany          83783942
# 12    night  70-100                      Comoros            869601
# 13  morning   46-60                       Rwanda          12952218
# 14  morning    0-20                  Timor-Leste           1318445
# 15     noon   60-70                      Denmark           5792202
# 16    night  70-100                 Sierra Leone           7976983
# 17  morning   46-60                     Dominica             71986
# 18  morning   46-60                      Ireland           4937786
# 19    night  70-100                     Pakistan         220892340
#
#     Land Area (KmÂ²)  Density (P/KmÂ²) Ground Truth  Predictions  Match
# 0             995450               103    happiness  [happiness]   True
# 1              28120                70           df         [df]   True
# 2             108560                64           df  [happiness]  False
# 3             627340                25      disgust    [disgust]   True
# 4                  1             26337        anger      [anger]   True
# 5              17200                67      sadness    [sadness]   True
# 6             397300                18           df  [happiness]  False
# 7              14870                89    happiness  [happiness]   True
# 8              27560               414    happiness  [happiness]   True
# 9             120340                55     surprise   [surprise]   True
# 10             39500               219      sadness    [sadness]   True
# 11            348560               240           df  [happiness]  False
# 12              1861               467      sadness    [sadness]   True
# 13             24670               525           df  [happiness]  False
# 14             14870                89           df         [df]   True
# 15             42430               137    happiness  [happiness]   True
# 16             72180               111    happiness  [happiness]   True
# 17               750                96    happiness  [happiness]   True
# 18             68890                72      sadness    [sadness]   True
# 19            770880               287    happiness  [happiness]   True

# %%
df['Match'].value_counts()
# Out:
# True     608
# False    191
# Name: Match, dtype: int64

# %%
# count correct and incorrect
result = df['Match'].value_counts()

# find correct count
correct = result.iloc[0]

# find incorrect count
incorrect = result.iloc[1]

# find total
total = correct + incorrect

# find accuracy
accuracy = correct / total

# print accuracy
accuracy
# Out:
# 0.7609511889862328

# %%
# Export the dataset
# df.to_csv("C:/Users/chand/OneDrive/Documents/Bruh/final-project-190688910-190988840/data/interim/multinomialNB_model_training.csv", index = False)

# %%
# Get the original dataset and run the model prediction on the Tweets (non-samples)
original_df = pd.read_csv("C:/Users/chand/OneDrive/Documents/Bruh/final-project-190688910-190988840/data/processed/original_dataset.csv", encoding = "ISO-8859-1")

original_df = original_df.dropna()
original_df['Predictions'] = ''
original_df.head(30)
# Out:
#             ID                                              Tweet Sentiment  \
# 0   1e551df661  think normally drawn people familiar similar u...  positive
# 1   5d470d3192  days aight cleaning mostly went mcds check had...  negative
# 2   0c89ab7ac0  happy star wars day im going make pasta get sh...  positive
# 3   98fe7210fa      ouch back im sick pamela anderson esque chest  negative
# 4   f0bb64692f  wishing sunny day might bothered get outta bed...  negative
# 5   3e2e986a68                                           im happy  negative
# 6   af3cb04ffc                      day long text conversation me   neutral
# 7   56437e0860       know exactly mean ive lost many friends feel  negative
# 8   c930341ca9                                       funny thanks  positive
# 9   5a17107aba  done absolutely nothing day todayhow pitiful t...  negative
# 10  4641062e9d               home now lol leaving monday flo rida   neutral
# 11  2d4944b8ef  knew worn sars mask plane socal feeling beginn...  negative
# 12  ac164fffd5  hello lovely followers love peace house lolz n...  positive
# 13  08a8d660b1  wish knew someone could hook us up friend told...  negative
# 14  218486ebee                               waching grays antomy   neutral
# 15  8994865218                             last song  really go     neutral
# 16  4f59a42713                      live tv coming xbox  live uk    neutral
# 17  fa5227b663                cant grandma probably phone get aim   neutral
# 18  f94213cfb8  im still waiting find caca stands  hoping thin...   neutral
# 19  e0794d1a3e  oh ok always wondered worked top ear done dont...   neutral
# 20  48b76ce5f4           day open  know do everyone leaving today   neutral
# 21  f532604ee6                                       want go work  negative
# 22  ddae59d08f  back  home  bathing kids ironing clothes hubby...   neutral
# 23  81a0d2766d  going back house pick dvds bapang pick ditos f...   neutral
# 24  4cbd2d23dc  vp goneso getting headache time coffee fight o...  negative
# 25  4e12593253         made wonderful breakfast get ready workout  positive
# 26  a479935bee                      waiti thought  till  sigjeans   neutral
# 27  2d882d5270                                  womp womp woooomp  positive
# 28  63fec8932a   hurts sister much potential isnt using waste ...   neutral
# 29  076dad1b7a                                       lol see king   neutral
#
#        Time     Age                   Country  Population -2020  \
# 0   morning   46-60                   Georgia         3989167.0
# 1      noon   60-70                     Libya         6871292.0
# 2     night  70-100                     Chile        19116201.0
# 3     night   31-45                  Portugal        10196709.0
# 4     night  70-100               Netherlands        17134872.0
# 5      noon   60-70                    Cyprus         1207359.0
# 6   morning   46-60                   Liberia         5057681.0
# 7     night   31-45                  Zimbabwe        14862924.0
# 8     night  70-100                    Mexico       128932753.0
# 9      noon   21-30                  Colombia        50882891.0
# 10     noon   21-30                  Paraguay         7132538.0
# 11  morning   46-60                    Serbia         8737371.0
# 12     noon   60-70                   Somalia        15893222.0
# 13     noon   21-30                Seychelles           98347.0
# 14  morning    0-20  Central African Republic         4829767.0
# 15    night   31-45                   Algeria        43851044.0
# 16  morning    0-20                   Jamaica         2961167.0
# 17     noon   60-70               North Korea        25778816.0
# 18     noon   60-70                    Tuvalu           11792.0
# 19  morning   46-60                   Eritrea         3546421.0
# 20    night  70-100             Liechtenstein           38128.0
# 21     noon   21-30                  Slovakia         5459642.0
# 22  morning    0-20                  Mongolia         3278290.0
# 23    night  70-100                   Namibia         2540905.0
# 24  morning   46-60                Mauritania         4649658.0
# 25  morning   46-60                    Kuwait         4270571.0
# 26    night   31-45              Sierra Leone         7976983.0
# 27  morning   46-60                  Mongolia         3278290.0
# 28  morning   46-60                  Dominica           71986.0
# 29  morning    0-20                    Rwanda        12952218.0
#
#     Land Area (KmÃÂ²)  Density (P/KmÃÂ²) Predictions
# 0              69490.0                57.0
# 1            1759540.0                 4.0
# 2             743532.0                26.0
# 3              91590.0               111.0
# 4              33720.0               508.0
# 5               9240.0               131.0
# 6              96320.0                53.0
# 7             386850.0                38.0
# 8            1943950.0                66.0
# 9            1109500.0                46.0
# 10            397300.0                18.0
# 11             87460.0               100.0
# 12            627340.0                25.0
# 13               460.0               214.0
# 14            622980.0                 8.0
# 15           2381740.0                18.0
# 16             10830.0               273.0
# 17            120410.0               214.0
# 18                30.0               393.0
# 19            101000.0                35.0
# 20               160.0               238.0
# 21             48088.0               114.0
# 22           1553560.0                 2.0
# 23            823000.0                 3.0
# 24           1030700.0                 5.0
# 25             17820.0               240.0
# 26             72180.0               111.0
# 27           1553560.0                 2.0
# 28               750.0                96.0
# 29             24670.0               525.0

# %%
# insert model predictions
for i, row in original_df.iterrows():
    text = [row['Tweet']]
    vector = cv.transform(text).toarray()
    original_df.at[i, 'Predictions'] = nv_model.predict(vector)

original_df.head(30)
# Out:
#             ID                                              Tweet Sentiment  \
# 0   1e551df661  think normally drawn people familiar similar u...  positive
# 1   5d470d3192  days aight cleaning mostly went mcds check had...  negative
# 2   0c89ab7ac0  happy star wars day im going make pasta get sh...  positive
# 3   98fe7210fa      ouch back im sick pamela anderson esque chest  negative
# 4   f0bb64692f  wishing sunny day might bothered get outta bed...  negative
# 5   3e2e986a68                                           im happy  negative
# 6   af3cb04ffc                      day long text conversation me   neutral
# 7   56437e0860       know exactly mean ive lost many friends feel  negative
# 8   c930341ca9                                       funny thanks  positive
# 9   5a17107aba  done absolutely nothing day todayhow pitiful t...  negative
# 10  4641062e9d               home now lol leaving monday flo rida   neutral
# 11  2d4944b8ef  knew worn sars mask plane socal feeling beginn...  negative
# 12  ac164fffd5  hello lovely followers love peace house lolz n...  positive
# 13  08a8d660b1  wish knew someone could hook us up friend told...  negative
# 14  218486ebee                               waching grays antomy   neutral
# 15  8994865218                             last song  really go     neutral
# 16  4f59a42713                      live tv coming xbox  live uk    neutral
# 17  fa5227b663                cant grandma probably phone get aim   neutral
# 18  f94213cfb8  im still waiting find caca stands  hoping thin...   neutral
# 19  e0794d1a3e  oh ok always wondered worked top ear done dont...   neutral
# 20  48b76ce5f4           day open  know do everyone leaving today   neutral
# 21  f532604ee6                                       want go work  negative
# 22  ddae59d08f  back  home  bathing kids ironing clothes hubby...   neutral
# 23  81a0d2766d  going back house pick dvds bapang pick ditos f...   neutral
# 24  4cbd2d23dc  vp goneso getting headache time coffee fight o...  negative
# 25  4e12593253         made wonderful breakfast get ready workout  positive
# 26  a479935bee                      waiti thought  till  sigjeans   neutral
# 27  2d882d5270                                  womp womp woooomp  positive
# 28  63fec8932a   hurts sister much potential isnt using waste ...   neutral
# 29  076dad1b7a                                       lol see king   neutral
#
#        Time     Age                   Country  Population -2020  \
# 0   morning   46-60                   Georgia         3989167.0
# 1      noon   60-70                     Libya         6871292.0
# 2     night  70-100                     Chile        19116201.0
# 3     night   31-45                  Portugal        10196709.0
# 4     night  70-100               Netherlands        17134872.0
# 5      noon   60-70                    Cyprus         1207359.0
# 6   morning   46-60                   Liberia         5057681.0
# 7     night   31-45                  Zimbabwe        14862924.0
# 8     night  70-100                    Mexico       128932753.0
# 9      noon   21-30                  Colombia        50882891.0
# 10     noon   21-30                  Paraguay         7132538.0
# 11  morning   46-60                    Serbia         8737371.0
# 12     noon   60-70                   Somalia        15893222.0
# 13     noon   21-30                Seychelles           98347.0
# 14  morning    0-20  Central African Republic         4829767.0
# 15    night   31-45                   Algeria        43851044.0
# 16  morning    0-20                   Jamaica         2961167.0
# 17     noon   60-70               North Korea        25778816.0
# 18     noon   60-70                    Tuvalu           11792.0
# 19  morning   46-60                   Eritrea         3546421.0
# 20    night  70-100             Liechtenstein           38128.0
# 21     noon   21-30                  Slovakia         5459642.0
# 22  morning    0-20                  Mongolia         3278290.0
# 23    night  70-100                   Namibia         2540905.0
# 24  morning   46-60                Mauritania         4649658.0
# 25  morning   46-60                    Kuwait         4270571.0
# 26    night   31-45              Sierra Leone         7976983.0
# 27  morning   46-60                  Mongolia         3278290.0
# 28  morning   46-60                  Dominica           71986.0
# 29  morning    0-20                    Rwanda        12952218.0
#
#     Land Area (KmÃÂ²)  Density (P/KmÃÂ²)  Predictions
# 0              69490.0                57.0         [df]
# 1            1759540.0                 4.0    [sadness]
# 2             743532.0                26.0  [happiness]
# 3              91590.0               111.0    [sadness]
# 4              33720.0               508.0  [happiness]
# 5               9240.0               131.0  [happiness]
# 6              96320.0                53.0  [happiness]
# 7             386850.0                38.0    [sadness]
# 8            1943950.0                66.0  [happiness]
# 9            1109500.0                46.0    [sadness]
# 10            397300.0                18.0  [happiness]
# 11             87460.0               100.0    [sadness]
# 12            627340.0                25.0  [happiness]
# 13               460.0               214.0    [sadness]
# 14            622980.0                 8.0  [happiness]
# 15           2381740.0                18.0  [happiness]
# 16             10830.0               273.0    [sadness]
# 17            120410.0               214.0    [sadness]
# 18                30.0               393.0    [sadness]
# 19            101000.0                35.0    [sadness]
# 20               160.0               238.0  [happiness]
# 21             48088.0               114.0  [happiness]
# 22           1553560.0                 2.0  [happiness]
# 23            823000.0                 3.0  [happiness]
# 24           1030700.0                 5.0    [sadness]
# 25             17820.0               240.0  [happiness]
# 26             72180.0               111.0    [sadness]
# 27           1553560.0                 2.0  [happiness]
# 28               750.0                96.0    [sadness]
# 29             24670.0               525.0  [happiness]
